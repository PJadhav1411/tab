# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
df=pd.read_csv("C:/Users/Admin/Desktop/Machine Learning/Practice/practice4/house.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
new_df=df.drop('price',axis='columns')
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(new_df,df.price)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(new_df)
y_pred
# Out:
# array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#        723767.12328767])

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red')
plt.plot(new_df,y_pred,color='blue')

# %%
model.predict([[3300]])
# Out:
# F:\anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %%
pr=model.predict(df[['area']])
df['pprice']=pr
df
# Out:
#    area   price         pprice
# 0  2600  550000  533664.383562
# 1  3000  565000  587979.452055
# 2  3200  610000  615136.986301
# 3  3600  680000  669452.054795
# 4  4000  725000  723767.123288
